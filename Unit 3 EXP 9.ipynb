# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

logs=[
{"IP":"192.168.1.1","Action":"Allow"},
{"IP":"192.168.1.2","Action":"Block"},
{"IP":"192.168.1.1","Action":"Allow"}
]

df=pd.DataFrame(logs)

print(df)

print("\nAggregation")

print(df.groupby("Action").count())
# Out:
#             IP Action
# 0  192.168.1.1  Allow
# 1  192.168.1.2  Block
# 2  192.168.1.1  Allow
#
# Aggregation
#         IP
# Action
# Allow    2
# Block    1
