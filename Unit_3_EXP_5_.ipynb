# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit_3_EXP_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
logs=[
"Failed Login",
"Failed Login",
"Success Login",
"Failed Login",
"Failed Login"
]

failed=logs.count("Failed Login")

print("Failed Attempts:",failed)

if failed>=4:
    print("Possible Brute Force Attack")
# Out:
# Failed Attempts: 4
# Possible Brute Force Attack
