# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

logs=pd.DataFrame({
"User":["A","A","B","B","C"],
"Status":["Fail","Fail","Success","Fail","Success"]
})

print(logs)

print("\nFailed Logins")

print(logs[logs["Status"]=="Fail"])

print("\nStatistics")

print(logs.groupby("Status").size())
# Out:
#   User   Status
# 0    A     Fail
# 1    A     Fail
# 2    B  Success
# 3    B     Fail
# 4    C  Success
#
# Failed Logins
#   User Status
# 0    A   Fail
# 1    A   Fail
# 3    B   Fail
#
# Statistics
# Status
# Fail       3
# Success    2
# dtype: int64
