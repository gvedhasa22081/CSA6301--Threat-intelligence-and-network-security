# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
task=input("Enter Task: ").lower()

tools={
"network scan":"Nmap",
"vulnerability scan":"OpenVAS",
"log analysis":"Splunk",
"packet capture":"Wireshark",
"malware analysis":"VirusTotal"
}

print("Recommended Tool:",tools.get(task,"No Recommendation"))
# Out:
# Enter Task: log analysis
# Recommended Tool: Splunk
