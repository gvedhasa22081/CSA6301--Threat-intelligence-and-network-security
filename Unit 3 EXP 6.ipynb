# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cpu=[20,25,30,28,90,24]

for value in cpu:
    if value>80:
        print("Anomaly Detected:",value,"%")
    else:
        print("Normal:",value,"%")
# Out:
# Normal: 20 %
# Normal: 25 %
# Normal: 30 %
# Normal: 28 %
# Anomaly Detected: 90 %
# Normal: 24 %
