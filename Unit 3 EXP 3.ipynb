# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
processes=[
"chrome.exe",
"powershell.exe",
"explorer.exe",
"cmd.exe",
"powershell.exe"
]

for p in processes:
    if p=="powershell.exe":
        print("Suspicious Process Found:",p)
# Out:
# Suspicious Process Found: powershell.exe
# Suspicious Process Found: powershell.exe
