# %% [markdown]
# <a href="https://colab.research.google.com/github/gvedhasa22081/CSA6301--Threat-intelligence-and-network-security/blob/main/Unit%203%20EXP%2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_name="invoice.exe"

strings=[
"cmd.exe",
"powershell",
"vssadmin",
"kernel32.dll"
]

print("Static Analysis")

for s in strings:
    print(s)

print("\nDynamic Analysis")

behavior=[
"Creates Process",
"Deletes Shadow Copies",
"Connects to IP",
"Encrypts Files"
]

for b in behavior:
    print(b)
# Out:
# Static Analysis
# cmd.exe
# powershell
# vssadmin
# kernel32.dll
#
# Dynamic Analysis
# Creates Process
# Deletes Shadow Copies
# Connects to IP
# Encrypts Files
